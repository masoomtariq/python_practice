# %% [markdown]
# | Code | Meaning                |
# | ---- | ---------------------- |
# | 200  | OK (Success)           |
# | 201  | Created (POST success) |
# | 400  | Bad Request            |
# | 401  | Unauthorized           |
# | 403  | Forbidden              |
# | 404  | Not Found              |
# | 500  | Server Error           |

# %%
import requests

# %% [markdown]
# ### Implement GET and POST requests

# %% [markdown]
# **Passing Data**
#
# * params= → for URL query parameters (GET)
#
# * data= → for form-encoded body data (POST)
#
# * json= → to send JSON body (modern APIs prefer this)

# %% [markdown]
# #### Example

# %%
requests.get("https://httpbin.org/get", params={"q": "python"})

requests.post("https://httpbin.org/post", data={"email": "test@example.com"})

requests.post("https://httpbin.org/post", json={"title": "Hello", "body": "World"})
# Out:
# <Response [200]>

# %% [markdown]
# **Response Attributes**
#
# These help you process the result:
#
# * status_code → check if the request succeeded
#
# * text → raw HTML/text
#
# * json() → convert JSON string to Python dict

# %% [markdown]
# #### **Examples**

# %% [markdown]
# ##### Get Request

# %%
# Sending a GET request to a website
response = requests.get("https://httpbin.org/get")

print("Status Code:", response.status_code)
print(response.text)
print('-'*100)
print(response.json())
# Out:
# Status Code: 200
# {
#   "args": {},
#   "headers": {
#     "Accept": "*/*",
#     "Accept-Encoding": "gzip, deflate",
#     "Host": "httpbin.org",
#     "User-Agent": "python-requests/2.32.3",
#     "X-Amzn-Trace-Id": "Root=1-6853d011-2f8f525664b25a3136fbb251"
#   },
#   "origin": "163.223.5.243",
#   "url": "https://httpbin.org/get"
# }
#
# ----------------------------------------------------------------------------------------------------
# {'args': {}, 'headers': {'Accept': '*/*', 'Accept-Encoding': 'gzip, deflate', 'Host': 'httpbin.org', 'User-Agent': 'python-requests/2.32.3', 'X-Amzn-Trace-Id': 'Root=1-6853d011-2f8f525664b25a3136fbb251'}, 'origin': '163.223.5.243', 'url': 'https://httpbin.org/get'}

# %% [markdown]
# ##### Post Request

# %%
url = "https://httpbin.org/post"
form_data = {
    "custname": "Masoom Tariq",
    "custtel": "03001234567",
    "custemail": "masoom@example.com",
    "size": "medium",
    "topping": "cheese",
    "delivery": "12:30",
    "comments": "No onions please"
}

response = requests.post(url, data=form_data)

print(response.status_code)
print(response.json()["form"])

print(response.text)  # Shows the form data you posted
# Out:
# 200
# {'comments': 'No onions please', 'custemail': 'masoom@example.com', 'custname': 'Masoom Tariq', 'custtel': '03001234567', 'delivery': '12:30', 'size': 'medium', 'topping': 'cheese'}
# {
#   "args": {},
#   "data": "",
#   "files": {},
#   "form": {
#     "comments": "No onions please",
#     "custemail": "masoom@example.com",
#     "custname": "Masoom Tariq",
#     "custtel": "03001234567",
#     "delivery": "12:30",
#     "size": "medium",
#     "topping": "cheese"
#   },
#   "headers": {
#     "Accept": "*/*",
#     "Accept-Encoding": "gzip, deflate",
#     "Content-Length": "142",
#     "Content-Type": "application/x-www-form-urlencoded",
#     "Host": "httpbin.org",
#     "User-Agent": "python-requests/2.32.3",
#     "X-Amzn-Trace-Id": "Root=1-6853cc6e-19f29a52152169d50d3c9bc5"
#   },
#   "json": null,
#   "origin": "163.223.5.255",
#   "url": "https://httpbin.org/post"
# }

# %%
# Posting new data
data = {
    "title": "Masoom's Post",
    "body": "This is a post made using Python!",
    "userId": 1
}

response = requests.post("https://httpbin.org/post", data=data)

print("Status Code:", response.status_code)
print("Response:", response.text)
print('-'*100)
print(response.json())
# Out:
# Status Code: 200
# Response: {
#   "args": {},
#   "data": "",
#   "files": {},
#   "form": {
#     "body": "This is a post made using Python!",
#     "title": "Masoom's Post",
#     "userId": "1"
#   },
#   "headers": {
#     "Accept": "*/*",
#     "Accept-Encoding": "gzip, deflate",
#     "Content-Length": "71",
#     "Content-Type": "application/x-www-form-urlencoded",
#     "Host": "httpbin.org",
#     "User-Agent": "python-requests/2.32.3",
#     "X-Amzn-Trace-Id": "Root=1-6853ced8-6aa280dd40df7aee07a0b610"
#   },
#   "json": null,
#   "origin": "163.223.5.250",
#   "url": "https://httpbin.org/post"
# }
#
# ----------------------------------------------------------------------------------------------------
# {'args': {}, 'data': '', 'files': {}, 'form': {'body': 'This is a post made using Python!', 'title': "Masoom's Post", 'userId': '1'}, 'headers': {'Accept': '*/*', 'Accept-Encoding': 'gzip, deflate', 'Content-Length': '71', 'Content-Type': 'application/x-www-form-urlencoded', 'Host': 'httpbin.org', 'User-Agent': 'python-requests/2.32.3', 'X-Amzn-Trace-Id': 'Root=1-6853ced8-6aa280dd40df7aee07a0b610'}, 'json': None, 'origin': '163.223.5.250', 'url': 'https://httpbin.org/post'}

# %%
url = "https://httpbin.org/get"
params = {
    "name": "Masoom",
    "course": "Python"
}

response = requests.get(url, params=params)

print(response.url)       # Shows the full URL with query string
print(response.text)    # Shows how the server received it

# %%
url = "https://httpbin.org/headers"
headers = {
    "User-Agent": "Masoom-App/1.0",
    "Authorization": "Bearer my-secret-token"
}

response = requests.get(url, headers=headers)

print(response.text)

# %%
url = "https://httpbin.org/get"
params = {"name": "Masoom"}
headers = {"User-Agent": "MasoomApp/1.0"}

response = requests.get(url, params=params, headers=headers)

print(response.url)
print(response.json())

# %% [markdown]
# #### Using 'params' and 'headers' in GET request

# %% [markdown]
# ##### Parameters in url

# %%
url = "http://jsonplaceholder.typicode.com/users"
response = requests.get(url)

print(response.text)
# Out:
# [
#   {
#     "id": 1,
#     "name": "Leanne Graham",
#     "username": "Bret",
#     "email": "Sincere@april.biz",
#     "address": {
#       "street": "Kulas Light",
#       "suite": "Apt. 556",
#       "city": "Gwenborough",
#       "zipcode": "92998-3874",
#       "geo": {
#         "lat": "-37.3159",
#         "lng": "81.1496"
#       }
#     },
#     "phone": "1-770-736-8031 x56442",
#     "website": "hildegard.org",
#     "company": {
#       "name": "Romaguera-Crona",
#       "catchPhrase": "Multi-layered client-server neural-net",
#       "bs": "harness real-time e-markets"
#     }
#   },
#   {
#     "id": 2,
#     "name": "Ervin Howell",
#     "username": "Antonette",
#     "email": "Shanna@melissa.tv",
#     "address": {
#       "street": "Victor Plains",
#       "suite": "Suite 879",
#       "city": "Wisokyburgh",
#       "zipcode": "90566-7771",
#       "geo": {
#         "lat": "-43.9509",
#         "lng": "-34.4618"
#       }
#     },
#     "phone": "010-692-6593 x09125",
#     "website": "anastasia.net",
#     "company": {
#       "name": "Deckow-Crist",
#       "catchPhrase": "Proactive didactic contingency",
#       "bs": "synergize scalable supply-chains"
#     }
#   },
#   {
#     "id": 3,
#     "name": "Clementine Bauch",
#     "username": "Samantha",
#     "email": "Nathan@yesenia.net",
#     "address": {
#       "street": "Douglas Extension",
#       "suite": "Suite 847",
#       "city": "McKenziehaven",
#       "zipcode": "59590-4157",
#       "geo": {
#         "lat": "-68.6102",
#         "lng": "-47.0653"
#       }
#     },
#     "phone": "1-463-123-4447",
#     "website": "ramiro.info",
#     "company": {
#       "name": "Romaguera-Jacobson",
#       "catchPhrase": "Face to face bifurcated interface",
#       "bs": "e-enable strategic applications"
#     }
#   },
#   {
#     "id": 4,
#     "name": "Patricia Lebsack",
#     "username": "Karianne",
#     "email": "Julianne.OConner@kory.org",
#     "address": {
#       "street": "Hoeger Mall",
#       "suite": "Apt. 692",
#       "city": "South Elvis",
#       "zipcode": "53919-4257",
#       "geo": {
#         "lat": "29.4572",
#         "lng": "-164.2990"
#       }
#     },
#     "phone": "493-170-9623 x156",
#     "website": "kale.biz",
#     "company": {
#       "name": "Robel-Corkery",
#       "catchPhrase": "Multi-tiered zero tolerance productivity",
#       "bs": "transition cutting-edge web services"
#     }
#   },
#   {
#     "id": 5,
#     "name": "Chelsey Dietrich",
#     "username": "Kamren",
#     "email": "Lucio_Hettinger@annie.ca",
#     "address": {
#       "street": "Skiles Walks",
#       "suite": "Suite 351",
#       "city": "Roscoeview",
#       "zipcode": "33263",
#       "geo": {
#         "lat": "-31.8129",
#         "lng": "62.5342"
#       }
#     },
#     "phone": "(254)954-1289",
#     "website": "demarco.info",
#     "company": {
#       "name": "Keebler LLC",
#       "catchPhrase": "User-centric fault-tolerant solution",
#       "bs": "revolutionize end-to-end systems"
#     }
#   },
#   {
#     "id": 6,
#     "name": "Mrs. Dennis Schulist",
#     "username": "Leopoldo_Corkery",
#     "email": "Karley_Dach@jasper.info",
#     "address": {
#       "street": "Norberto Crossing",
#       "suite": "Apt. 950",
#       "city": "South Christy",
#       "zipcode": "23505-1337",
#       "geo": {
#         "lat": "-71.4197",
#         "lng": "71.7478"
#       }
#     },
#     "phone": "1-477-935-8478 x6430",
#     "website": "ola.org",
#     "company": {
#       "name": "Considine-Lockman",
#       "catchPhrase": "Synchronised bottom-line interface",
#       "bs": "e-enable innovative applications"
#     }
#   },
#   {
#     "id": 7,
#     "name": "Kurtis Weissnat",
#     "username": "Elwyn.Skiles",
#     "email": "Telly.Hoeger@billy.biz",
#     "address": {
#       "street": "Rex Trail",
#       "suite": "Suite 280",
#       "city": "Howemouth",
#       "zipcode": "58804-1099",
#       "geo": {
#         "lat": "24.8918",
#         "lng": "21.8984"
#       }
#     },
#     "phone": "210.067.6132",
#     "website": "elvis.io",
#     "company": {
#       "name": "Johns Group",
#       "catchPhrase": "Configurable multimedia task-force",
#       "bs": "generate enterprise e-tailers"
#     }
#   },
#   {
#     "id": 8,
#     "name": "Nicholas Runolfsdottir V",
#     "username": "Maxime_Nienow",
#     "email": "Sherwood@rosamond.me",
#     "address": {
#       "street": "Ellsworth Summit",
#       "suite": "Suite 729",
#       "city": "Aliyaview",
#       "zipcode": "45169",
#       "geo": {
#         "lat": "-14.3990",
#         "lng": "-120.7677"
#       }
#     },
#     "phone": "586.493.6943 x140",
#     "website": "jacynthe.com",
#     "company": {
#       "name": "Abernathy Group",
#       "catchPhrase": "Implemented secondary concept",
#       "bs": "e-enable extensible e-tailers"
#     }
#   },
#   {
#     "id": 9,
#     "name": "Glenna Reichert",
#     "username": "Delphine",
#     "email": "Chaim_McDermott@dana.io",
#     "address": {
#       "street": "Dayna Park",
#       "suite": "Suite 449",
#       "city": "Bartholomebury",
#       "zipcode": "76495-3109",
#       "geo": {
#         "lat": "24.6463",
#         "lng": "-168.8889"
#       }
#     },
#     "phone": "(775)976-6794 x41206",
#     "website": "conrad.com",
#     "company": {
#       "name": "Yost and Sons",
#       "catchPhrase": "Switchable contextually-based project",
#       "bs": "aggregate real-time technologies"
#     }
#   },
#   {
#     "id": 10,
#     "name": "Clementina DuBuque",
#     "username": "Moriah.Stanton",
#     "email": "Rey.Padberg@karina.biz",
#     "address": {
#       "street": "Kattie Turnpike",
#       "suite": "Suite 198",
#       "city": "Lebsackbury",
#       "zipcode": "31428-2261",
#       "geo": {
#         "lat": "-38.2386",
#         "lng": "57.2232"
#       }
#     },
#     "phone": "024-648-3804",
#     "website": "ambrose.net",
#     "company": {
#       "name": "Hoeger LLC",
#       "catchPhrase": "Centralized empowering task-force",
#       "bs": "target end-to-end models"
#     }
#   }
# ]

# %%
url = "http://jsonplaceholder.typicode.com/users"
params = {
    "id": 1
}

response = requests.get(url, params=params)

print(response.url)
print(f"\nparameter in url: '{response.url.split('?')[-1]}'")
print("\n", response.text)
# Out:
# http://jsonplaceholder.typicode.com/users?id=1
#
# parameter in url: 'id=1'
#
#  [
#   {
#     "id": 1,
#     "name": "Leanne Graham",
#     "username": "Bret",
#     "email": "Sincere@april.biz",
#     "address": {
#       "street": "Kulas Light",
#       "suite": "Apt. 556",
#       "city": "Gwenborough",
#       "zipcode": "92998-3874",
#       "geo": {
#         "lat": "-37.3159",
#         "lng": "81.1496"
#       }
#     },
#     "phone": "1-770-736-8031 x56442",
#     "website": "hildegard.org",
#     "company": {
#       "name": "Romaguera-Crona",
#       "catchPhrase": "Multi-layered client-server neural-net",
#       "bs": "harness real-time e-markets"
#     }
#   }
# ]

# %% [markdown]
# **🧠 params is a Python dictionary that gets converted into URL query parameters.**

# %% [markdown]
# ##### Headers

# %%
url = "https://httpbin.org/headers"
headers = {
    "User-Agent": "Masoom-App/1.0",
    "Authorization": "Bearer my-secret-token"
}

response = requests.get(url, headers=headers)

print(response.text)
# Out:
# {
#   "headers": {
#     "Accept": "*/*",
#     "Accept-Encoding": "gzip, deflate",
#     "Authorization": "Bearer my-secret-token",
#     "Host": "httpbin.org",
#     "User-Agent": "Masoom-App/1.0",
#     "X-Amzn-Trace-Id": "Root=1-6853c734-7b3166f053a5f6bb21dee8f9"
#   }
# }

# %% [markdown]
# **💡 headers are like the ID card or passport your request sends to the API.**

# %% [markdown]
# ##### Combined

# %%
url = "https://httpbin.org/get"
params = {"name": "Masoom"}
headers = {"User-Agent": "MasoomApp/1.0"}

response = requests.get(url, params=params, headers=headers)

print(response.url)
print(response.text)
# Out:
# https://httpbin.org/get?name=Masoom
# {
#   "args": {
#     "name": "Masoom"
#   },
#   "headers": {
#     "Accept": "*/*",
#     "Accept-Encoding": "gzip, deflate",
#     "Host": "httpbin.org",
#     "User-Agent": "MasoomApp/1.0",
#     "X-Amzn-Trace-Id": "Root=1-6853c78b-4250495757a4175278f51aca"
#   },
#   "origin": "163.223.5.246",
#   "url": "https://httpbin.org/get?name=Masoom"
# }

# %% [markdown]
# | Argument  | Use for                     | Visible in URL? | Example        |
# | --------- | --------------------------- | --------------- | -------------- |
# | `params`  | Send query data             | ✅ Yes           | `?key=value`   |
# | `headers` | Metadata (auth, user-agent) | ❌ No            | Custom headers |

# %% [markdown]
# ### Practice Error Handling using Python’s Exception Mechanisms -- Handling the Exceptions

# %%
# Initializing the testing url

non_exist = "http://nonexistent.api"
timeout = "https://httpbin.org/delay/5"
bad_domain = "http://thisurldoesnotexist.tld"

url200 = "https://httpbin.org/status/200"
url201 = "https://httpbin.org/status/201"
url400 = "https://httpbin.org/status/400"
url401 = "https://httpbin.org/status/401"
url403 = "https://httpbin.org/status/403"
url404 = "https://httpbin.org/status/404"
url500 = "https://httpbin.org/status/500"

# %%
try:
    response = requests.get(url400, timeout=2)
    response.raise_for_status()
except requests.exceptions.Timeout:
    print("⏱ Request timed out!")
except requests.exceptions.ConnectionError:
    print("❌ Could not connect to the server.")
except requests.exceptions.HTTPError as e:
    print("⚠️ HTTP error:", e)
except requests.exceptions.RequestException:
    print("🔁 General request error.")
else:
    print("No exception occur")

print(response.text)
# Out:
# ⚠️ HTTP error: 400 Client Error: BAD REQUEST for url: https://httpbin.org/status/400

# %% [markdown]
# The difference betweeen the **Non-existing url and the unreachable url** Example (https://httpbin.org/notfound) and (http://idonotexist.tld):
#
# * Non-existing URL (404 or 500): is when the domain is valid **i.e. 'httpbin.org'** but the path of the domain is not valid **i.e. '/notfound'**.
# * Connection Error (Unreachable url): is when the domain is not valid **i.e. 'idonotexist.tld'** or Your system cannot reach the server at all **i.e. 'No internet Connection'**.

# %%
# using the non existing url
try:
    requests.get(non_exist)
# Catch all errors
except requests.exceptions.RequestException as e:
    print("Something went wrong:")
# Out:
# Something went wrong:

# %%
# Using the testing api for check the timeout Exception
try:
    response = requests.get(timeout, timeout=2)  # Server will respond after 5s
except requests.exceptions.Timeout as e:
    print("Request timed out!", e)
# Out:
# Request timed out! HTTPSConnectionPool(host='httpbin.org', port=443): Read timed out. (read timeout=2)

# %%
# Using the url with invalid domain name
try:
    response = requests.get(bad_domain)
except requests.exceptions.ConnectionError as e:
    print("Connection failed:", e)
# Out:
# Connection failed: HTTPConnectionPool(host='thisurldoesnotexist.tld', port=80): Max retries exceeded with url: / (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x000002B3E6923D10>: Failed to resolve 'thisurldoesnotexist.tld' ([Errno 11001] getaddrinfo failed)"))

# %%
# Using url with bad HTTP 
try:
    response = requests.get(url400)
    response.raise_for_status() # Raise error if response was not OK. i.e. 4** or 5**
except requests.exceptions.HTTPError as e:
    print("HTTP error occurred:", e)
# Out:
# HTTP error occurred: 400 Client Error: BAD REQUEST for url: https://httpbin.org/status/400

# %% [markdown]
# ### Review Real-World APIs (Weather, Social Media, Maps)

# %%
response = requests.get("http://api.openweathermap.org/data/2.5/forecast?id=524901&appid={835a9bdd9544a703d07c6053a59eb37d}")

# %%
response = requests.get("https://newsapi.org/v2/everything?q=Apple&from=2025-06-14&sortBy=popularity&apiKey=78b551748de14966acaca3df1d270e6d", params= {'publishedAt': '2025-06-14T10:30:00Z'})

# %%
response.json()
# Out:
# {'status': 'ok',
#  'totalResults': 4939,
#  'articles': [{'source': {'id': 'the-verge', 'name': 'The Verge'},
#    'author': 'David Pierce',
#    'title': 'Life with the Nintendo Switch 2',
#    'description': "The Nintendo Switch 2 is great. In many ways, it's exactly what we hoped for: a Switch, only better. And yet there's something… underwhelming about it. Maybe it's unfair, but we've come to expect Nintendo to consistently amaze us with either how its consoles …",
#    'url': 'https://www.theverge.com/the-vergecast/688057/nintendo-switch-2-review-vergecast',
#    'urlToImage': 'https://platform.theverge.com/wp-content/uploads/sites/2/2025/06/VRG_VST_0617_Site.jpg?quality=90&strip=all&crop=0%2C10.732984293194%2C100%2C78.534031413613&w=1200',
#    'publishedAt': '2025-06-17T12:15:27Z',
#    'content': 'On The Vergecast: the pros and cons and future of Nintendos new console.\r\nOn The Vergecast: the pros and cons and future of Nintendos new console.\r\nThe Nintendo Switch 2 is great. In many ways, its e… [+1453 chars]'},
#   {'source': {'id': 'the-verge', 'name': 'The Verge'},
#    'author': 'Jay Peters',
#    'title': 'The Atlantic is making a big push into games',
#    'description': 'Daily puzzle games are seemingly everywhere right now, and starting today, you’ll be able to add a new stop to your puzzle rotation: The Atlantic. The publication is launching a new hub for its growing game offerings, including already available games like Br…',
#    'url': 'https://www.theverge.com/news/687721/the-atlantic-games-hub-bracket-city',
#    'urlToImage': 'https://platform.theverge.com/wp-content/uploads/sites/2/2025/06/Games.png?quality=90&strip=all&crop=0%2C3.4613147178592%2C100%2C93.077370564282&w=1200',
#    'publishedAt': '2025-06-17T02:25:12Z',
#    'content': 'Daily puzzle games are seemingly everywhere right now, and starting today, you’ll be able to add a new stop to your puzzle rotation: The Atlantic.\n\nThe publication is launching a new hub for its grow… [+2957 chars]'},
#   {'source': {'id': 'the-verge', 'name': 'The Verge'},
#    'author': 'Andrew J. Hawkins',
#    'title': 'The Nissan Leaf is finally getting the makeover it deserves',
#    'description': 'Nissan revealed new details about the upcoming 2026 Leaf, which will return as a crossover SUV with up to 303 miles of estimated range, dual charge ports, and Google’s software built-in. The reborn Leaf will reach dealerships in the US starting this fall at a…',
#    'url': 'https://www.theverge.com/news/687542/nissan-leaf-2026-refresh-specs-range-charging',
#    'urlToImage': 'https://platform.theverge.com/wp-content/uploads/sites/2/2025/06/250308_All-new_Nissan_LEAF_Dynamic_Pictures_13.jpg?quality=90&strip=all&crop=0%2C10.732984293194%2C100%2C78.534031413613&w=1200',
#    'publishedAt': '2025-06-16T21:50:07Z',
#    'content': 'The Nissan Leaf is finally getting the makeover it deserves\r\nWith over 300 miles of estimated range, a Tesla charge port, and native Android software, the pioneering EV is back and better than ever.\r… [+6657 chars]'},
#   {'source': {'id': None, 'name': 'Gizmodo.com'},
#    'author': 'Mike Fazioli',
#    'title': 'Apple Slashes 2024 M4 Mac Mini Price Below Black Friday, Feels Like a Surprise Clearout Sale on Amazon',
#    'description': "Apple's famous little desktop computer now comes with a huge upgrade, including iPhone mirroring and Apple Intelligence.",
#    'url': 'https://gizmodo.com/apple-slashes-2024-m4-mac-mini-price-below-black-friday-feels-like-a-surprise-clearout-sale-on-amazon-2000616685',
#    'urlToImage': 'https://gizmodo.com/app/uploads/2025/06/Mac-Mini-2024-1200x675.jpg',
#    'publishedAt': '2025-06-17T12:10:18Z',
#    'content': 'The Mac Mini blew away the computing world when it debuted in 2005 a Mac desktop computer with all of the processing power and cool features of its larger siblings, but at a fraction of the size. In … [+2209 chars]'},
#   {'source': {'id': None, 'name': 'Gizmodo.com'},
#    'author': 'James Pero',
#    'title': 'With AI Siri Delayed, Apple’s AirPods Pro 3 May Be Next',
#    'description': 'Do AirPods Pro have a Siri problem, too?',
#    'url': 'https://gizmodo.com/with-ai-siri-delayed-apples-airpods-pro-3-may-be-next-2000616296',
#    'urlToImage': 'https://gizmodo.com/app/uploads/2025/06/AirPods-2-1200x675.jpg',
#    'publishedAt': '2025-06-16T21:30:56Z',
#    'content': 'If you were itching for a new pair of AirPods Pro, you may want to clip those fingernails because that itch could persist for another year. According to yet another Apple analyst, the AirPods Pro 3 m… [+3188 chars]'},
#   {'source': {'id': None, 'name': 'Gizmodo.com'},
#    'author': 'Gizmodo Deals',
#    'title': 'Amazon Clearing Out Smart TVs, This 42″ Full HD Model Sold for Peanuts Before Prime Day',
#    'description': 'For what you’d pay for a restaurant meal, you get a 42-inch smart TV for your home.',
#    'url': 'https://gizmodo.com/amazon-clearing-out-smart-tvs-this-42-full-hd-model-sold-for-peanuts-before-prime-day-2000617146',
#    'urlToImage': 'https://gizmodo.com/app/uploads/2024/11/insignia-fire-tv.jpg',
#    'publishedAt': '2025-06-17T20:12:56Z',
#    'content': 'While OLED TVs are their own attraction, none of them will be under $1,000 and they’re not necessarily the most convenient for all parts of the house. For the majority of consumers, a smart TV like t… [+1711 chars]'},
#   {'source': {'id': None, 'name': 'Gizmodo.com'},
#    'author': 'Sabina Graves',
#    'title': 'I Have Questions About the Official ‘Fantastic Four’ Pizza',
#    'description': "The food tie-ins with Marvel's next movie offer some very curious choices.",
#    'url': 'https://gizmodo.com/i-have-questions-about-the-official-fantastic-four-pizza-2000616477',
#    'urlToImage': 'https://gizmodo.com/app/uploads/2025/06/Little-Caesars-Fantastic-four--1200x675.jpg',
#    'publishedAt': '2025-06-16T21:15:53Z',
#    'content': 'Giving the foodie world a spin is Marvel Studios’The Fantastic Four: First Steps, and here’s a preview of the upcoming snack tie-ins at major chain restaurants and snack companies. If you thought tha… [+2756 chars]'},
#   {'source': {'id': None, 'name': 'BBC News'},
#    'author': None,
#    'title': "The reality behind Trump's incredible investment claims",
#    'description': "The president's impact on investment in the US is far more incremental than he has claimed.",
#    'url': 'https://www.bbc.com/news/articles/clynl129kd2o',
#    'urlToImage': 'https://ichef.bbci.co.uk/news/1024/branded_news/e2c2/live/97fc85c0-485e-11f0-bbaa-4bc03e0665b7.jpg',
#    'publishedAt': '2025-06-16T00:44:27Z',
#    'content': 'US President Donald Trump may have called tariffs his favourite word in the dictionary. But when it comes to obsessions, business investment has got to be close. \r\nAs of last month, he said more than… [+6437 chars]'},
#   {'source': {'id': None, 'name': 'Android Central'},
#    'author': 'nirave@hot.tech (Nirave Gondhia) , Nirave Gondhia',
#    'title': "Apple should ditch Siri for Gemini and Google Cloud, here's why",
#    'description': "Apple has faced numerous challenges with Apple Intelligence, and with Gemini so far ahead of the new Siri, here's why it's time for Apple to let Google do the hard work of building a chatbot.",
#    'url': 'https://www.androidcentral.com/phones/apple-iphone/apple-should-ditch-siri-for-gemini-and-google-cloud-heres-why',
#    'urlToImage': 'https://cdn.mos.cms.futurecdn.net/S4NsoYm7QWdNXLMmer3dyR.png',
#    'publishedAt': '2025-06-17T07:00:00Z',
#    'content': 'It’s been a year since Apple unveiled Apple Intelligence, its long-awaited foray into the world of artificial intelligence on phones. The company promised many features, but a year on, these have bee… [+8201 chars]'},
#   {'source': {'id': None, 'name': 'Android Central'},
#    'author': 'bradypsnyder@gmail.com (Brady Snyder) , Brady Snyder',
#    'title': 'YouTube Music is borrowing this handy feature from Spotify and Apple Music',
#    'description': 'Spotify and Apple Music have had lyric sharing for a while, but YouTube Music is only now adding the feature in a big win for subscribers.',
#    'url': 'https://www.androidcentral.com/apps-software/youtube/youtube-music-is-borrowing-this-handy-feature-from-spotify-and-apple-music',
#    'urlToImage': 'https://cdn.mos.cms.futurecdn.net/KmKrgnNUK4XiYTj2BbWkP6.jpg',
#    'publishedAt': '2025-06-17T21:18:10Z',
#    'content': "<ul><li>YouTube Music is rolling out support for sharing lyrics today, after first testing the functionality in April 2025.</li><li>It's available on the latest version of the YouTube Music app for i… [+2285 chars]"},
#   {'source': {'id': None, 'name': 'Android Central'},
#    'author': 'techkritiko@gmail.com (Jay Bonggolto) , Jay Bonggolto',
#    'title': 'Spotify just made it super easy to grab your favorite tracks on Wear OS',
#    'description': 'Spotify has made downloading tunes to your Wear OS smartwatch a lot less of a pain.',
#    'url': 'https://www.androidcentral.com/apps-software/spotify/spotify-just-made-it-super-easy-to-grab-your-favorite-tracks-on-your-wear-os-watch',
#    'urlToImage': 'https://cdn.mos.cms.futurecdn.net/yH2oW8cgLZGodvbZuW9d69.jpg',
#    'publishedAt': '2025-06-17T17:24:06Z',
#    'content': 'What you need to know\r\n<ul><li>Spotify just made life easier for Premium users by letting you send playlists straight to any signed-in device, like smartwatches.</li><li>Whether it’s your phone, lapt… [+2394 chars]'},
#   {'source': {'id': None, 'name': 'Android Central'},
#    'author': 'michael.hicks@futurenet.com (Michael L Hicks) , Michael L Hicks',
#    'title': 'Best of AWE 2025: The most promising XR gadgets from Niantic, Sony, Android XR, and more',
#    'description': 'From futuristic XR prototypes to next-gen headsets and smart glasses, these were my favorite demos on the AWE 2025 show floor!',
#    'url': 'https://www.androidcentral.com/gaming/virtual-reality/best-of-awe-2025-coolest-xr-demos-niantic-viture-sony-android-xr',
#    'urlToImage': 'https://cdn.mos.cms.futurecdn.net/KjXjRj8V8ZVyZPvBWEtgsM.jpg',
#    'publishedAt': '2025-06-14T23:00:00Z',
#    'content': 'Across a whirlwind three days of Augmented World Expo USA 2025 in Long Beach, California, I tested out demos from some of the biggest names in XR, while also checking out prototypes from start-ups th… [+9918 chars]'},
#   {'source': {'id': None, 'name': 'Android Central'},
#    'author': 'michael.hicks@futurenet.com (Michael L Hicks) , Michael L Hicks',
#    'title': "Meta and Google made big promises at AWE, but AR glasses' future is still messy",
#    'description': "Everyone at Augmented World Expo, shockingly, believes AR glasses will take off. But Google, Meta, and other XR brands disagree on how it'll happen.",
#    'url': 'https://www.androidcentral.com/gaming/virtual-reality/meta-google-described-conflicting-visions-of-ar-glasses-future-at-awe-2025',
#    'urlToImage': 'https://cdn.mos.cms.futurecdn.net/YBwahwoTws6TWH5aHpZUaM.jpg',
#    'publishedAt': '2025-06-16T20:24:32Z',
#    'content': 'Smart glasses are undeniably exploding. Speakers at Augmented World Expo 2025 panels on the future of smart glasses were passionately bullish on its future. But once specifically asked about augmente… [+8324 chars]'},
#   {'source': {'id': None, 'name': 'MacRumors'},
#    'author': 'Juli Clover',
#    'title': 'Apple Seeds First Beta of macOS Sequoia 15.6',
#    'description': 'Apple today seeded the first beta of an upcoming macOS Sequoia 15.6 update to developers for testing purposes, with the software coming a month after Apple released \u200cmacOS Sequoia\u200c 15.5.\n\n\n\n\n\nDevelopers can opt-in to the \u200cmacOS Sequoia\u200c beta through the Softw…',
#    'url': 'https://www.macrumors.com/2025/06/16/apple-seeds-macos-sequoia-15-6-beta-1/',
#    'urlToImage': 'https://images.macrumors.com/t/zZbcqD0-kgQ9SCr6AnSkKJIiULE=/2500x/article-new/2024/06/macOS-Sequoia-Feature.jpg',
#    'publishedAt': '2025-06-16T17:10:48Z',
#    'content': 'Apple today seeded the first beta of an upcoming macOS Sequoia 15.6 update to developers for testing purposes, with the software coming a month after Apple released \u200cmacOS Sequoia\u200c 15.5.\r\nDevelopers … [+462 chars]'},
#   {'source': {'id': None, 'name': 'MacRumors'},
#    'author': 'Tim Hardwick',
#    'title': 'Apple Watch Ultra 3 Finally Coming After Two-Year Hiatus',
#    'description': 'Apple will finally deliver the Apple Watch Ultra 3 sometime this year, according to analyst Jeff Pu of GF Securities Hong Kong (via @jukanlosreve). \n\n\n\n\n\nThe analyst expects both the Apple Watch Series 11 and Apple Watch Ultra 3 to arrive this year (likely al…',
#    'url': 'https://www.macrumors.com/2025/06/16/apple-watch-ultra-3-finally-coming-2025/',
#    'urlToImage': 'https://images.macrumors.com/t/P4LdECugnko3tpuGqLbffEs9dJ0=/2500x/article-new/2024/09/apple-watch-ultra-2-new-black.jpg',
#    'publishedAt': '2025-06-16T15:45:00Z',
#    'content': 'Apple will finally deliver the Apple Watch Ultra 3 sometime this year, according to analyst Jeff Pu of GF Securities Hong Kong (via @jukanlosreve). \r\nThe analyst expects both the Apple Watch Series 1… [+1362 chars]'},
#   {'source': {'id': None, 'name': 'MacRumors'},
#    'author': 'Juli Clover',
#    'title': 'Apple Seeds First Beta of iOS 18.6 to Developers',
#    'description': 'Apple today seeded the first betas of upcoming iOS 18.6 and iPadOS 18.6 updates to developers for testing purposes, with the update coming over a month after Apple released iOS 18.5 and iPadOS 18.5.\n\n\n\n\n\niOS 18.6 and iPadOS 18.6 can be downloaded from the Set…',
#    'url': 'https://www.macrumors.com/2025/06/16/apple-seeds-ios-18-6-beta-1/',
#    'urlToImage': 'https://images.macrumors.com/t/yss4k6jWqFSi8YxrvqpuqbQVbEI=/2500x/article-new/2025/03/iOS-18.6-Feature-Real-Mock.jpg',
#    'publishedAt': '2025-06-16T17:06:59Z',
#    'content': 'Apple today seeded the first betas of upcoming iOS 18.6 and iPadOS 18.6 updates to developers for testing purposes, with the update coming over a month after Apple released iOS 18.5 and iPadOS 18.5.\r… [+618 chars]'},
#   {'source': {'id': None, 'name': 'MacRumors'},
#    'author': 'Mitchel Broussard',
#    'title': 'Amazon Takes $100 Off Huge Collection of Apple Watch Series 10 Models, Available From $299',
#    'description': 'Amazon is offering numerous all-time low prices on Apple Watch Series 10 devices today, including both GPS and cellular models at $100 off original prices. Best Buy is matching these prices in many cases.\n\n\n\nNote: MacRumors is an affiliate partner with Amazon…',
#    'url': 'https://www.macrumors.com/2025/06/16/amazon-apple-watch-series-10/',
#    'urlToImage': 'https://images.macrumors.com/t/jdzZpnmsQKKjg1ZYdw-RuMLwE7Y=/2500x/article-new/2025/03/apple-watch-series-10-blue-hue.jpeg',
#    'publishedAt': '2025-06-16T17:33:41Z',
#    'content': 'Amazon is offering numerous all-time low prices on Apple Watch Series 10 devices today, including both GPS and cellular models at $100 off original prices. Best Buy is matching these prices in many c… [+900 chars]'},
#   {'source': {'id': None, 'name': 'MacRumors'},
#    'author': 'Hartley Charlton',
#    'title': "Court Upholds Regulator's Case Against Apple Over App Store",
#    'description': 'Apple has lost a legal challenge in the Netherlands after a Dutch court ruled that the company abused its dominant market position by imposing restrictive payment terms on dating app developers (via Reuters).\n\n\n\n\n\n\n\nThe ruling was issued earlier today by the …',
#    'url': 'https://www.macrumors.com/2025/06/16/court-upholds-case-against-apple/',
#    'urlToImage': 'https://images.macrumors.com/t/fvnq7lgIjn-BQ5WsIW1FtaA-BEg=/2250x/article-new/2022/01/iOS-App-Store-General-Feature-Black.jpg',
#    'publishedAt': '2025-06-16T15:37:49Z',
#    'content': 'Apple has lost a legal challenge in the Netherlands after a Dutch court ruled that the company abused its dominant market position by imposing restrictive payment terms on dating app developers (via … [+1658 chars]'},
#   {'source': {'id': None, 'name': 'MacRumors'},
#    'author': 'Juli Clover',
#    'title': 'Apple Seeds First Betas of visionOS 2.6, tvOS 18.6, and watchOS 11.6',
#    'description': 'Apple today provided developers with the first betas of upcoming visionOS 2.6, tvOS 18.6, and watchOS 11.6 updates for testing purposes. The software comes over a month after Apple released visionOS 2.5, tvOS 18.5, and watchOS 11.5. \n\n\n\n\n\nThe betas are availa…',
#    'url': 'https://www.macrumors.com/2025/06/16/apple-seeds-watchos-11-6-beta-1/',
#    'urlToImage': 'https://images.macrumors.com/t/rq2lbiKUJ4mBoI2uAPRvK66-wnk=/2500x/article-new/2025/04/General-visionOS-watchOS-and-tvOS-Betas-Feature-Redux.jpg',
#    'publishedAt': '2025-06-16T17:12:25Z',
#    'content': 'Apple today provided developers with the first betas of upcoming visionOS 2.6, tvOS 18.6, and watchOS 11.6 updates for testing purposes. The software comes over a month after Apple released visionOS … [+295 chars]'},
#   {'source': {'id': None, 'name': 'MacRumors'},
#    'author': 'Joe Rossignol',
#    'title': 'Apple Launches 2023 Mac Mini Repair Program Due to Power Issue',
#    'description': 'Apple today launched a repair program for Mac mini models with the M2 chip, after it determined that a "very small percentage" of these computers may no longer power on. No other Mac mini models are part of this program.\n\n\n\n\n\nIf your Mac mini has exhibited th…',
#    'url': 'https://www.macrumors.com/2025/06/13/apple-launches-2023-mac-mini-repair-program/',
#    'urlToImage': 'https://images.macrumors.com/t/2fNsxdETt5aS_NobBCL0JKFupA0=/1600x/article-new/2023/01/Mac-mini-M2-2023.jpeg',
#    'publishedAt': '2025-06-14T03:31:46Z',
#    'content': 'Apple today launched a repair program for Mac mini models with the M2 chip, after it determined that a "very small percentage" of these computers may no longer power on. No other Mac mini models are … [+559 chars]'},
#   {'source': {'id': None, 'name': 'MacRumors'},
#    'author': 'Tim Hardwick',
#    'title': 'AirPods Pro 3 Not Launching Until Next Year, Claims Analyst',
#    'description': "Apple may launch the AirPods Pro 3 in 2026, according to analyst Jeff Pu of GF Securities Hong Kong, contradicting earlier predictions of a much sooner release.\n\n\n\n\n\nPu's Apple product timeline (via @jukanlosreve) comes as a bit of a surprise. Bloomberg's Mar…",
#    'url': 'https://www.macrumors.com/2025/06/16/airpods-pro-3-not-launching-until-next-year/',
#    'urlToImage': 'https://images.macrumors.com/t/z2sZZhvZCmSf2ZVhWb-tH0zaPF0=/2500x/article-new/2025/04/AirPods-Pro-3-Mock-Feature.jpg',
#    'publishedAt': '2025-06-16T11:52:46Z',
#    'content': "Apple may launch the AirPods Pro 3 in 2026, according to analyst Jeff Pu of GF Securities Hong Kong, contradicting earlier predictions of a much sooner release.\r\nPu's Apple product timeline (via @juk… [+1773 chars]"},
#   {'source': {'id': None, 'name': 'MacRumors'},
#    'author': 'Tim Hardwick',
#    'title': 'iPhone Sales Jump 15% in April-May as Apple Reclaims China Lead',
#    'description': "iPhone sales climbed 15% year-over-year during April and May, signaling Apple's strongest two-month performance for the period since the pandemic, according to preliminary data from Counterpoint Research's Market Pulse Global Monthly Smartphone Sales Report.\n…",
#    'url': 'https://www.macrumors.com/2025/06/17/iphone-sales-jump-apple-reclaims-china-lead/',
#    'urlToImage': 'https://images.macrumors.com/t/NHloYA07lXYNraPhCHvmog9VT_M=/3840x/article-new/2025/03/Apple-iPhone-16-family-lineup.jpg',
#    'publishedAt': '2025-06-17T11:05:20Z',
#    'content': "iPhone sales climbed 15% year-over-year during April and May, signaling Apple's strongest two-month performance for the period since the pandemic, according to preliminary data from Counterpoint Rese… [+1640 chars]"},
#   {'source': {'id': None, 'name': 'MacRumors'},
#    'author': 'Tim Hardwick',
#    'title': "Apple's 2025 Back to School Sale Now Live, Offering Free Accessories With Purchases",
#    'description': 'Apple today launched its annual Back to School promotion, offering eligible students, educators, and parents free accessories worth up to $199 when purchasing select Mac and iPad models through September 30.\n\n\n\n\n\nThe 2025 promotion is different from last year…',
#    'url': 'https://www.macrumors.com/2025/06/17/apple-back-to-school-2025-now-live/',
#    'urlToImage': 'https://images.macrumors.com/t/zXCm88lGaZ5vr0bxiHlhR83_skg=/1600x/article-new/2025/06/bts-overlay-store-202505-header.jpg',
#    'publishedAt': '2025-06-17T12:04:25Z',
#    'content': 'Apple today launched its annual Back to School promotion, offering eligible students, educators, and parents free accessories worth up to $199 when purchasing select Mac and iPad models through Septe… [+1799 chars]'},
#   {'source': {'id': None, 'name': 'MacRumors'},
#    'author': 'Mitchel Broussard',
#    'title': 'AirPods Pro 2 Available for Lowest Price of the Year So Far at $169, Plus AirPods 4 at $99',
#    'description': 'Amazon has the AirPods Pro 2 for $169.00 this weekend, down from $249.00. Free delivery options provide an estimated delivery date of around June 19, while Prime members should get the headphones sooner in most cases.\n\n\n\nNote: MacRumors is an affiliate partne…',
#    'url': 'https://www.macrumors.com/2025/06/14/airpods-pro-2-169-airpods-4-99/',
#    'urlToImage': 'https://images.macrumors.com/t/T07At4JWez19K3RtsMef30uvPQs=/2500x/article-new/2023/05/Airpods-Pro-2-Discount-Feature-Blue-Triad.jpg',
#    'publishedAt': '2025-06-14T18:51:29Z',
#    'content': 'Amazon has the AirPods Pro 2 for $169.00 this weekend, down from $249.00. Free delivery options provide an estimated delivery date of around June 19, while Prime members should get the headphones soo… [+761 chars]'},
#   {'source': {'id': None, 'name': 'MacRumors'},
#    'author': 'Joe Rossignol',
#    'title': "Satechi's New Accessory Lets You Add Up to 8TB of Storage to Mac Mini",
#    'description': 'Accessory maker Satechi has announced that it has released a new NVMe SSD enclosure that is specially designed for the latest Mac mini.\n\n\n\n\n\nThe slim aluminum enclosure is the same size as the Mac mini models with M4 and M4 Pro chips, allowing it to sit atop …',
#    'url': 'https://www.macrumors.com/2025/06/17/satechi-usb4-slim-nvme-ssd-enclosure/',
#    'urlToImage': 'https://images.macrumors.com/t/fmQrsRexFykoklb8ykwYrE0aYmQ=/1601x/article-new/2025/06/Satechi-USB-4-Mac-Mini-NVMe-SSD-Enclosure.jpg',
#    'publishedAt': '2025-06-17T16:00:00Z',
#    'content': 'Accessory maker Satechi has announced that it has released a new NVMe SSD enclosure that is specially designed for the latest Mac mini.\r\nThe slim aluminum enclosure is the same size as the Mac mini m… [+976 chars]'},
#   {'source': {'id': None, 'name': 'MacRumors'},
#    'author': 'Joe Rossignol',
#    'title': 'iOS 26 Lets You Set Custom Ringtones Without Using GarageBand',
#    'description': 'The dust is beginning to settle on iOS 26, but there is one more smaller improvement that we wanted to make sure that we highlighted: the ability to set custom ringtones on the iPhone without using the GarageBand app.\n\n\n\n\n\nTo set a custom ringtone on iOS 26, …',
#    'url': 'https://www.macrumors.com/2025/06/17/ios-26-use-as-ringtone-option/',
#    'urlToImage': 'https://images.macrumors.com/t/6WszYq0TEnKVkudFDZC4ATrrAl0=/2500x/article-new/2025/02/iOS-18.4-Ambient-Music-Feature.jpg',
#    'publishedAt': '2025-06-17T18:16:20Z',
#    'content': 'The dust is beginning to settle on iOS 26, but there is one more smaller improvement that we wanted to make sure that we highlighted: the ability to set custom ringtones on the iPhone without using t… [+780 chars]'},
#   {'source': {'id': None, 'name': 'MacRumors'},
#    'author': 'Joe Rossignol',
#    'title': 'iOS 26 Improves Screenshots in Three Ways',
#    'description': 'iOS 26 includes three small but meaningful changes for screenshots.\n\n\n\n\n\nThe upcoming software update adds a new Screen Capture menu to the Settings app, under General. In it, there are a few useful toggles.\n\n\n\nFirst, there is now an option for HDR screenshot…',
#    'url': 'https://www.macrumors.com/2025/06/17/ios-26-improves-screenshots-in-three-ways/',
#    'urlToImage': 'https://images.macrumors.com/t/svhrPae00rKbhnRktRYM0rFv6FI=/1920x/article-new/2025/06/iOS-26-Screenshots.jpg',
#    'publishedAt': '2025-06-17T21:24:05Z',
#    'content': 'iOS 26 includes three small but meaningful changes for screenshots.\r\nThe upcoming software update adds a new Screen Capture menu to the Settings app, under General. In it, there are a few useful togg… [+1598 chars]'},
#   {'source': {'id': None, 'name': 'MacRumors'},
#    'author': 'Mitchel Broussard',
#    'title': 'Anker Offers MacRumors Readers 20% Off Collection of Chargers, Hubs, Batteries, and More',
#    'description': "MacRumors readers can get 20 percent off a collection of Anker's best charging accessories this month. In order to get this deal, head to Anker's website and add an accessory to your cart, then enter the code Ankermacrumors2025 at checkout to see the discount…",
#    'url': 'https://www.macrumors.com/2025/06/17/anker-macrumors-readers-20-off-2/',
#    'urlToImage': 'https://images.macrumors.com/t/-nSxz8wN4BglLjRdF9mOAV28hqk=/2500x/article-new/2025/04/anker-spring-deals-compressed.jpg',
#    'publishedAt': '2025-06-17T17:47:01Z',
#    'content': "MacRumors readers can get 20 percent off a collection of Anker's best charging accessories this month. In order to get this deal, head to Anker's website and add an accessory to your cart, then enter… [+1511 chars]"},
#   {'source': {'id': None, 'name': 'CNET'},
#    'author': 'David Carnoy',
#    'title': 'New AirPods Pro 3 Coming in 2025? Rumors, Leaks and Everything We Know',
#    'description': "Heart rate sensors? A touch screen case? Here's what might be coming to Apple's new noise-canceling earbuds later this year. Plus, there's one key feature I'd like to see.",
#    'url': 'https://www.cnet.com/tech/mobile/new-airpods-pro-3-coming-in-2025-rumors-leaks-and-everything-we-know/',
#    'urlToImage': 'https://www.cnet.com/a/img/resize/a3fc3896d86dd25f74e9c81ac8999f050597f663/hub/2025/03/04/52a1a7bf-de97-40fb-9a68-76c5ca1b33ee/fake-airpods-pro-with-lcd-in-case.jpg?auto=webp&fit=crop&height=675&width=1200',
#    'publishedAt': '2025-06-16T16:16:00Z',
#    'content': "It's been almost three years since Apple updated its AirPods Pro, and all signs point to a new version releasing sometime in 2025. Last year was a bit of a mixed bag: Apple introduced the all-new Air… [+11520 chars]"},
#   {'source': {'id': None, 'name': 'CNET'},
#    'author': 'Amanda Kooser',
#    'title': "My T-Mobile 5G Home Internet Experience: 5 Things I Love and a Few I Don't",
#    'description': "I've been using this cellular home internet service for nearly three years. It's superior to my old DSL, but it's not perfect.",
#    'url': 'https://www.cnet.com/home/internet/my-t-mobile-5g-home-internet-experience-5-things-i-love-and-a-few-i-dont/',
#    'urlToImage': 'https://www.cnet.com/a/img/resize/02a9b6286bb469b6128b4d9a95e67edea4f4d856/hub/2024/09/25/bb120ff9-8846-4fea-8627-1c0a4fd660b2/tmobile3.jpg?auto=webp&fit=crop&height=675&width=1200',
#    'publishedAt': '2025-06-14T10:30:00Z',
#    'content': 'Albuquerque, New Mexico: home of green chiles, 300 days of sunshine, the International Balloon Fiesta... and achingly slow internet. Of the top 100 cities in the US, Albuquerque ranks 85th, according… [+8725 chars]'},
#   {'source': {'id': 'business-insider', 'name': 'Business Insider'},
#    'author': 'amok@insider.com (Aaron Mok)',
#    'title': 'A biotech company sold over 500,000 AI-powered health testing kits. Two C-suite leaders share how they kept science at the center.',
#    'description': 'Viome is combining science and AI to provide dietary advice and detect diseases. Two company execs share how they use the MVP mindset for innovation.',
#    'url': 'https://www.businessinsider.com/viome-science-technology-leaders-collaborate-ai-health-testing-2025-6',
#    'urlToImage': 'https://i.insider.com/684c3c2cf748d8c055f3a746?width=1200&format=jpeg',
#    'publishedAt': '2025-06-17T17:04:48Z',
#    'content': 'This article is part of "Build IT: Connectivity," a series about tech powering better business.\r\nViome is aiming to transform disease detection, starting with the gut.\r\nThe Washington-based biotech s… [+9732 chars]'},
#   {'source': {'id': None, 'name': 'MacRumors'},
#    'author': 'Juli Clover',
#    'title': "Discounted Apple Watch Series 10 Now Available From Apple's U.S. Refurbished Store",
#    'description': 'Apple today stocked its U.S. refurbished store with Apple Watch Series 10 models, offering the latest Apple Watch devices at a discount for the first time since their launch last September.\n\n\n\n\n\nThe refurbished Apple Watch Series 10 models are discounted by a…',
#    'url': 'https://www.macrumors.com/2025/06/17/apple-watch-series-10-refurbished/',
#    'urlToImage': 'https://images.macrumors.com/t/ZuGGhA3CJ944A0Ll7Bf605BHnkc=/2500x/article-new/2025/02/apple-watch-series-10-new-purple.jpeg',
#    'publishedAt': '2025-06-17T19:46:44Z',
#    'content': 'Apple today stocked its U.S. refurbished store with Apple Watch Series 10 models, offering the latest Apple Watch devices at a discount for the first time since their launch last September.\r\nThe refu… [+1324 chars]'},
#   {'source': {'id': None, 'name': 'MacRumors'},
#    'author': 'Juli Clover',
#    'title': 'Apple Saves $300 Million After Appeals Court Win in LTE Patent Fight',
#    'description': 'Apple today won a victory in its ongoing patent infringement litigation with Texas-based patent troll Optis, reports Reuters.\n\n\n\n\n\nThe U.S. Court of Appeals for the Federal Circuit today threw out a prior jury verdict that would have forced Apple to pay $300 …',
#    'url': 'https://www.macrumors.com/2025/06/17/apple-optis-patent-fight-appeals-win/',
#    'urlToImage': 'https://images.macrumors.com/t/5EkMryMVSdA7yXAby8WWhrZtxuM=/2500x/article-new/2025/05/iphone-16-pro-purple.jpeg',
#    'publishedAt': '2025-06-17T19:30:16Z',
#    'content': 'Apple today won a victory in its ongoing patent infringement litigation with Texas-based patent troll Optis, reports Reuters.\r\nThe U.S. Court of Appeals for the Federal Circuit today threw out a prio… [+1590 chars]'},
#   {'source': {'id': None, 'name': 'MacRumors'},
#    'author': 'Juli Clover',
#    'title': "Spigen's Latest Apple Watch Charger Looks Like a Retro iMac",
#    'description': "Spigen recently expanded its C1 series with a https://www.spigen.com/products/apple-watch-classic-c1-charger-stand that's designed to look like Apple's retro iMac G3. For those unfamiliar with Spigen's C1 accessories, they are modeled after classic Apple prod…",
#    'url': 'https://www.macrumors.com/2025/06/16/spigen-apple-watch-charger-imac/',
#    'urlToImage': 'https://images.macrumors.com/t/tzW5fhsZSKH9UMuq8K4moP1BZ1g=/3925x/article-new/2025/06/satechi-imac-apple-watch-charger.jpg',
#    'publishedAt': '2025-06-16T21:37:04Z',
#    'content': "Spigen recently expanded its C1 series with a https://www.spigen.com/products/apple-watch-classic-c1-charger-stand that's designed to look like Apple's retro iMac G3. For those unfamiliar with Spigen… [+1201 chars]"},
#   {'source': {'id': None, 'name': 'MacRumors'},
#    'author': 'MacRumors Staff',
#    'title': 'Top Stories: WWDC 2025 Recap With iOS 26, macOS Tahoe, and More',
#    'description': "Apple's annual developer conference has come to a close for 2025, and WWDC was packed with announcements right from the start of Monday's keynote. As expected, we got a unified numbering scheme across Apple's platforms, as well as a redesign that makes for a …",
#    'url': 'https://www.macrumors.com/2025/06/14/top-stories-wwdc-2025-recap/',
#    'urlToImage': 'https://images.macrumors.com/t/bpUYto4C1qIJQydqxHe34NVWUxM=/1600x/article-new/2025/06/top-stories-2025-06-14.jpg',
#    'publishedAt': '2025-06-14T13:00:00Z',
#    'content': "Apple's annual developer conference has come to a close for 2025, and WWDC was packed with announcements right from the start of Monday's keynote. As expected, we got a unified numbering scheme acros… [+6157 chars]"},
#   {'source': {'id': None, 'name': 'MacRumors'},
#    'author': 'Joe Rossignol',
#    'title': 'Apple to Start Releasing Public Betas of AirPods Firmware Updates',
#    'description': 'Apple plans to offer public betas of AirPods firmware updates for the first time.\n\n\n\n\n\nThe public will be able to test upcoming AirPods firmware updates through the free Apple Beta Software Program, with no Apple Developer account required.\n\n\n\n"New public bet…',
#    'url': 'https://www.macrumors.com/2025/06/15/airpods-firmware-public-betas/',
#    'urlToImage': 'https://images.macrumors.com/t/TnKKOjUHUD6oX0AosW_W9pw_HcQ=/2500x/article-new/2024/10/AirPods-Pro-2-New-Firmware-Feature-Cool.jpg',
#    'publishedAt': '2025-06-15T19:19:46Z',
#    'content': 'Apple plans to offer public betas of AirPods firmware updates for the first time.\r\nThe public will be able to test upcoming AirPods firmware updates through the free Apple Beta Software Program, with… [+1026 chars]'},
#   {'source': {'id': None, 'name': 'MacRumors'},
#    'author': 'Hartley Charlton',
#    'title': 'watchOS 26 Moves Latest Apple Watch Models to New Architecture',
#    'description': 'watchOS 26 brings a significant upgrade to the Apple Watch\'s architecture, transitioning the latest models to full arm64.\n\n\n\n\n\nThe change was revealed in Apple\'s "What\'s new in watchOS 26" video for developers. The Apple Watch Series 9, Series 10, and Apple W…',
#    'url': 'https://www.macrumors.com/2025/06/16/watchos-26-moves-apple-watch-to-new-architecture/',
#    'urlToImage': 'https://images.macrumors.com/t/MRrekiS9uXT5weoZjYS8WLyB2VU=/1865x/article-new/2025/06/watchos-26.jpg',
#    'publishedAt': '2025-06-16T13:33:25Z',
#    'content': 'watchOS 26 brings a significant upgrade to the Apple Watch\'s architecture, transitioning the latest models to full arm64.\r\nThe change was revealed in Apple\'s "What\'s new in watchOS 26" video for deve… [+1948 chars]'},
#   {'source': {'id': None, 'name': 'MacRumors'},
#    'author': 'Joe Rossignol',
#    'title': 'iOS 18.6 Beta Coming Soon Alongside iOS 26 Beta',
#    'description': 'iOS 26 has been stealing the spotlight over the last week, but there is still another iOS 18 update on the horizon, according to a leaker.\n\n\n\n\n\nThe first iOS 18.6 beta should be coming very soon, as a private account on X with a proven track record of sharing…',
#    'url': 'https://www.macrumors.com/2025/06/16/ios-18-6-beta-coming-soon/',
#    'urlToImage': 'https://images.macrumors.com/t/yss4k6jWqFSi8YxrvqpuqbQVbEI=/2500x/article-new/2025/03/iOS-18.6-Feature-Real-Mock.jpg',
#    'publishedAt': '2025-06-16T13:27:07Z',
#    'content': 'iOS 26 has been stealing the spotlight over the last week, but there is still another iOS 18 update on the horizon, according to a leaker.\r\nThe first iOS 18.6 beta should be coming very soon, as a pr… [+1790 chars]'},
#   {'source': {'id': None, 'name': 'MacRumors'},
#    'author': 'Juli Clover',
#    'title': 'See iPadOS 26 Multitasking in Action',
#    'description': 'iPadOS 26 is going to change the way that you use your iPad, and it turns working on the \u200ciPad\u200c into a much more Mac-like experience. Apple introduced a whole new multitasking system, which you can get a first look at in our video.\n\n\n\n\r\nSubscribe to the MacRu…',
#    'url': 'https://www.macrumors.com/2025/06/17/ipados-26-multitasking/',
#    'urlToImage': 'https://images.macrumors.com/t/DE2TxZd65peYfslaDRkUsjpqx24=/2500x/article-new/2025/06/iPadOS-26-Multitasking-Thumb-3.jpg',
#    'publishedAt': '2025-06-17T17:29:31Z',
#    'content': 'iPadOS 26 is going to change the way that you use your iPad, and it turns working on the \u200ciPad\u200c into a much more Mac-like experience. Apple introduced a whole new multitasking system, which you can g… [+1838 chars]'},
#   {'source': {'id': None, 'name': 'MacRumors'},
#    'author': 'Tim Hardwick',
#    'title': 'iOS 26: Five Changes Coming to Your iPhone Lock Screen',
#    'description': 'With iOS 26, Apple has made some additions to the iPhone Lock Screen that aim to make it more customizable than ever. \n\n\n\n\n\nOf course, things can always change before the software makes its way to the general iPhone-owning public, but here are five new things…',
#    'url': 'https://www.macrumors.com/2025/06/17/ios-26-five-changes-coming-to-iphone-lock-screen/',
#    'urlToImage': 'https://images.macrumors.com/t/4ga-jkH1wMZ_v7Xw5BHVUP4i4Nw=/3840x/article-new/2025/06/new-iphone-lockscreen-ios-26.jpg',
#    'publishedAt': '2025-06-17T15:46:41Z',
#    'content': 'With iOS 26, Apple has made some additions to the iPhone Lock Screen that aim to make it more customizable than ever. \r\nOf course, things can always change before the software makes its way to the ge… [+2608 chars]'},
#   {'source': {'id': None, 'name': 'MacRumors'},
#    'author': 'Joe Rossignol',
#    'title': 'iPhone 17 Pro Launching in Three Months With These 12 New Features',
#    'description': 'The iPhone 17 Pro and iPhone 17 Pro Max are three months away, and there are plenty of rumors about the devices.\n\n\n\n\n\nBelow, we recap key changes rumored for the iPhone 17 Pro models as of June 2025:<ul><li>Aluminum frame: iPhone 17 Pro models are rumored to …',
#    'url': 'https://www.macrumors.com/2025/06/14/iphone-17-pro-and-pro-max-rumors/',
#    'urlToImage': 'https://images.macrumors.com/t/Ka9AiEjd1-um03YQzxAPPlLN9K8=/2500x/article-new/2025/04/iPhone-17-Pro-Blue-Feature-Tighter-Crop.jpg',
#    'publishedAt': '2025-06-15T00:45:00Z',
#    'content': 'The iPhone 17 Pro and iPhone 17 Pro Max are three months away, and there are plenty of rumors about the devices.\r\nBelow, we recap key changes rumored for the iPhone 17 Pro models as of June 2025:\r\n<u… [+2669 chars]'},
#   {'source': {'id': None, 'name': 'MacRumors'},
#    'author': 'Mitchel Broussard',
#    'title': 'Get the M3 MacBook Air for Just $699 at Best Buy',
#    'description': 'Best Buy this week is taking $200 off several models of the M3 MacBook Air from 2024, with deals focusing mainly on the 13-inch versions of the computer. Prices start at just $699.00 for the 256GB M3 MacBook Air, down from $899.00.\n\n\n\nNote: MacRumors is an af…',
#    'url': 'https://www.macrumors.com/2025/06/16/m3-macbook-air-699-best-buy/',
#    'urlToImage': 'https://images.macrumors.com/t/S2qW_Vd4-v38l_ZaK5V6C7aYnpQ=/2500x/article-new/2024/04/macbook-air-m3-green.jpg',
#    'publishedAt': '2025-06-16T14:08:56Z',
#    'content': 'Best Buy this week is taking $200 off several models of the M3 MacBook Air from 2024, with deals focusing mainly on the 13-inch versions of the computer. Prices start at just $699.00 for the 256GB M3… [+987 chars]'},
#   {'source': {'id': None, 'name': 'NPR'},
#    'author': 'Geoff Brumfiel',
#    'title': 'Trump wants a Golden Dome missile defense shield. Is that realistic?',
#    'description': "Since last week, Israel has been attacking Iran's nuclear facilities, along with many other targets around the country. Iran has fired hundreds of missiles in response. NPR correspondent Geoff Brumfiel has been watching all of this very closely because Israel…",
#    'url': 'https://www.npr.org/2025/06/17/1266983856/trump-golden-dome-israel-iran-iron-dome',
#    'urlToImage': 'https://media.npr.org/assets/img/2025/06/16/6.17.25-ep_wide-e6b9f3cdd4a5acbaeb9e430c800eceb2a2a6c4a5.jpg?s=1400&c=100&f=jpeg',
#    'publishedAt': '2025-06-17T07:00:59Z',
#    'content': 'President Donald Trump speaks about Golden Dome in the Oval Office of the White House in May of this year.\r\nAlex Brandon/AP\r\nThis year, President Trump requested funding from Congress for a "Golden D… [+1399 chars]'},
#   {'source': {'id': None, 'name': 'NPR'},
#    'author': 'Amelia Edelman',
#    'title': '10 ways travel insiders deal with annoying flight delays',
#    'description': 'Clever advice on how to quickly rebook your flight, skip long lines and avoid flight issues in the future. One tip? Try queuing up for an agent in the airport lounge.',
#    'url': 'https://www.npr.org/2025/06/17/nx-s1-5359391/flight-delay-flight-cancellation-rebook-ticket',
#    'urlToImage': 'https://npr.brightspotcdn.com/dims3/default/strip/false/crop/6000x3375+0+625/resize/1400/quality/100/format/jpeg/?url=http%3A%2F%2Fnpr-brightspot.s3.amazonaws.com%2F99%2F09%2Fc1c20b8a41a790e08c606c071404%2Flk-travel-awry-gettyimages-2199142469.jpg',
#    'publishedAt': '2025-06-17T09:00:00Z',
#    'content': 'Earlier this year, my partner, two kids and I got stuck in Los Angeles for three days. We were on a layover, trying to get to Hawaii for a family reunion. But the airline kept canceling our next flig… [+6318 chars]'},
#   {'source': {'id': None, 'name': 'Slashdot.org'},
#    'author': 'EditorDavid',
#    'title': 'Do People Actually Want Smart Glasses Now?',
#    'description': 'It\'s the technology "Google tried (and failed at) more than a decade ago," writes CNN. (And Meta and Amazon have also previously tried releasing glasses with cameras, speakers and voice assistants.) \nYet this week Snap announced that "it\'s building AI-equippe…',
#    'url': 'https://slashdot.org/story/25/06/14/1648202/do-people-actually-want-smart-glasses-now',
#    'urlToImage': 'https://a.fsdn.com/sd/topics/ai_64.png',
#    'publishedAt': '2025-06-15T11:34:00Z',
#    'content': 'It\'s the technology "Google tried (and failed at) more than a decade ago," writes CNN. (And Meta and Amazon have also previously tried releasing glasses with cameras, speakers and voice assistants.)Y… [+2080 chars]'},
#   {'source': {'id': 'business-insider', 'name': 'Business Insider'},
#    'author': 'Sarah Perkel',
#    'title': "'Slow down' and 'deeply observe' the company culture when starting a new job, says ex-Apple director",
#    'description': 'Bob Baxley said most major tech companies have very "powerful" cultures — and they can sometimes accidentally follow you into your new job.',
#    'url': 'https://www.businessinsider.com/tech-companies-culture-apple-car-wash-new-job-bob-baxley-2025-6',
#    'urlToImage': 'https://i.insider.com/684c5d9e85e81483682c13ef?width=1200&format=jpeg',
#    'publishedAt': '2025-06-15T09:59:01Z',
#    'content': 'Bob Baxley, a former director of design at Apple, said the company\'s culture is "powerful.\'Reuters\r\n<ul><li>A former Apple director recommends you take time to recalibrate so you can better adjust to… [+4061 chars]'},
#   {'source': {'id': 'business-insider', 'name': 'Business Insider'},
#    'author': 'Brent D. Griffiths',
#    'title': 'Trump Organization announces mobile plan, which will offer a gold-colored phone that costs $499',
#    'description': "Donald Trump Jr. and Eric Trump announced that the president's company is getting into the mobile business and will make smartphones too.",
#    'url': 'https://www.businessinsider.com/trump-mobile-smartphone-gold-mobile-t1-2025-6',
#    'urlToImage': 'https://i.insider.com/68501e3885e81483682c26e8?width=1200&format=jpeg',
#    'publishedAt': '2025-06-16T14:03:10Z',
#    'content': "Eric Trump and Donald Trump Jr. unveiled the next Trump-branded service: a wireless phone plan with an accompanying smartphone.Richard Drew/AP\r\n<ul><li>Donald Trump's sons announced a Trump Mobile se… [+1999 chars]"},
#   {'source': {'id': 'business-insider', 'name': 'Business Insider'},
#    'author': 'Dominick Reuter,Katherine Tangalakis-Lippert,Alex Bitter',
#    'title': 'We visited 3 Target stores across the US for clues as to why the retail chain is struggling',
#    'description': 'We visited three Target stores across the US to get a sense of what the retail chain could be doing better as sales growth stalls.',
#    'url': 'https://www.businessinsider.com/target-store-visits-why-company-struggling-images-2025-6',
#    'urlToImage': 'https://i.insider.com/684b42ec85e81483682c035b?width=1200&format=jpeg',
#    'publishedAt': '2025-06-16T09:55:01Z',
#    'content': 'A shopper looks at kitchen appliances in a Target in Wisconsin.Dominick Reuter/Business Insider\r\n<ul><li>Target has struggled to grow sales in recent years as competitors pull ahead.</li><li>Some ana… [+10938 chars]'},
#   {'source': {'id': 'business-insider', 'name': 'Business Insider'},
#    'author': 'Joi-Marie McKenzie',
#    'title': 'Economic anxiety or not, Americans are still prioritizing Euro summer travel',
#    'description': 'In this Saturday edition of Business Insider today, we are talking about why Euro summer travel is still all the rage.',
#    'url': 'https://www.businessinsider.com/bi-today-sunglasses-socks-seafood-exercise-cancer-2025-6',
#    'urlToImage': 'https://i.insider.com/684c8c70f748d8c055f3b575?width=1200&format=jpeg',
#    'publishedAt': '2025-06-14T10:41:01Z',
#    'content': 'Many Americans prioritize travel, especially to bucket list destinations.Marco Bottigelli/Getty Images\r\n<ul><li>This post originally appeared in the BI Today newsletter.</li><li>You can sign up for B… [+7030 chars]'},
#   {'source': {'id': 'business-insider', 'name': 'Business Insider'},
#    'author': "Lara O'Reilly,Lucia Moses",
#    'title': 'The 25 most innovative CMOs of 2025',
#    'description': "Business Insider's 10th annual list of the most innovative CMOs includes big companies like Walmart and challengers like Milani Cosmetics.",
#    'url': 'https://www.businessinsider.com/meet-2025s-25-most-innovative-cmos-2025-6',
#    'urlToImage': 'https://i.insider.com/684997b8f748d8c055f3798d?width=1200&format=jpeg',
#    'publishedAt': '2025-06-17T14:00:01Z',
#    'content': 'From left: Leslie Berland, Don McGuire, Laura Jones, Dara Treseder, and Doug Sweeny.Alyssa Powell/BI\r\nCMOs have a tough job.They have to show business results by capitalizing on trends and reaching n… [+38939 chars]'},
#   {'source': {'id': None, 'name': 'Harvard Business Review'},
#    'author': None,
#    'title': 'How to Get Out of the Hybrid Work Rut',
#    'description': 'A conversation with HR experts Peter Cappelli and Ranya Nehmeh on making the most of compromise.',
#    'url': 'https://hbr.org/podcast/2025/06/how-to-get-out-of-the-hybrid-work-rut',
#    'urlToImage': 'https://hbr.org/resources/images/article_assets/2025/02/wide-ideacast_25.png',
#    'publishedAt': '2025-06-17T12:20:00Z',
#    'content': 'ADI IGNATIUS: I’m Adi Ignatius.\r\nALISON BEARD: I’m Alison Beard, and this is the HBR IdeaCast.\r\nADI IGNATIUS: All right. Alison, I feel like in this age of flexible work, there’s still a lot of disag… [+31983 chars]'},
#   {'source': {'id': None, 'name': 'Harvard Business Review'},
#    'author': None,
#    'title': 'How Do I Adapt My Leadership as My Company Grows?',
#    'description': 'A conversation with an entrepreneurial leader about how to scale her leadership.',
#    'url': 'https://hbr.org/podcast/2025/06/how-do-i-adapt-my-leadership-as-my-company-grows',
#    'urlToImage': 'https://hbr.org/resources/images/article_assets/2024/11/wide-coaching-real-leaders-24.png',
#    'publishedAt': '2025-06-16T13:22:00Z',
#    'content': 'MURIEL WILKINS: I am Muriel Wilkins, and this is Coaching Real Leaders, part of the HBR Podcast Network. I’m a longtime executive coach who works with highly successful leaders who’ve hit a bump in t… [+37323 chars]'},
#   {'source': {'id': None, 'name': 'Hipertextual'},
#    'author': 'Gabriel Erard',
#    'title': 'El Nissan Leaf eléctrico se renueva con un diseño superaerodinámico y hasta 600 km de autonomía',
#    'description': 'El Nissan Leaf se ha ganado un lugar de bastante respeto en el mercado de los coches eléctricos gracias a su prolongada presencia en el segmento. Y el fabricante japonés acaba de presentar la tercera generación de este modelo, que ahora se ofrece en forma de …',
#    'url': 'http://hipertextual.com/2025/06/nuevo-nissan-leaf-electrico-caracteristicas-precio-y-disponibilidad',
#    'urlToImage': 'https://imgs.hipertextual.com/wp-content/uploads/2025/06/All-new_Nissan_LEAF_Dynamic_Pictures_10-scaled.jpg',
#    'publishedAt': '2025-06-17T15:43:36Z',
#    'content': 'El Nissan Leaf se ha ganado un lugar de bastante respeto en el mercado de los coches eléctricos gracias a su prolongada presencia en el segmento. Y el fabricante japonés acaba de presentar la tercera… [+3412 chars]'},
#   {'source': {'id': None, 'name': 'Hipertextual'},
#    'author': 'Gabriel Erard',
# ...
#   {'source': {'id': None, 'name': 'Xataka.com'},
#    'author': 'Alejandro Alcolea',
#    'title': 'Córdoba lleva 20 años intentando terminar una carretera. Ahora se han topado con un problemón: ruinas mozárabes',
#    'description': 'Hacer obras en una ciudad como Córdoba es una tarea de riesgo. Cada cierto tiempo, en ciudades españolas encontramos nuevos vestigios de eras anteriores. Un ejemplo son las ruinas bajo la Puerta del Sol o el yacimiento de Huerta de Otero en Mérida. Lo de Córd…',
#    'url': 'https://www.xataka.com/magnet/carretera-cordoba-acumula-lustros-retraso-excavando-se-han-topado-obstaculo-monumental-ruinas-mozarabes',
#    'urlToImage': 'https://i.blogs.es/7f11b7/cordoba/840_560.jpeg',
#    'publishedAt': '2025-06-15T11:31:29Z',
#    'content': 'Hacer obras en una ciudad como Córdoba es una tarea de riesgo. Cada cierto tiempo, en ciudades españolas encontramos nuevos vestigios de eras anteriores. Un ejemplo son las ruinas bajo la Puerta del … [+3959 chars]'},
#   {'source': {'id': None, 'name': 'Xataka.com'},
#    'author': 'Amparo Babiloni',
#    'title': 'Tras Shein, China tiene entre manos una nueva arma para devorar la industria de la moda: una IA que predice tendencias',
#    'description': 'En la competitiva industria de la moda, acertar con las tendencias es crucial y supone la diferencia entre un éxito de ventas y un lote de ropa sin vender. Cuentan en SCMP como una startup china está ayudando a marcas como Nike y GAP a tomar decisiones más ac…',
#    'url': 'https://www.xataka.com/robotica-e-ia/shein-china-tiene-manos-nueva-arma-para-devorar-industria-moda-ia-que-predice-tendencias',
#    'urlToImage': 'https://i.blogs.es/71be5f/shopping-mall-1316787_1920/840_560.jpeg',
#    'publishedAt': '2025-06-17T17:31:07Z',
#    'content': 'En la competitiva industria de la moda, acertar con las tendencias es crucial y supone la diferencia entre un éxito de ventas y un lote de ropa sin vender. Cuentan en SCMP como una startup china está… [+6005 chars]'},
#   {'source': {'id': None, 'name': 'Daringfireball.net'},
#    'author': 'John Gruber',
#    'title': '★ The Talk Show Live From WWDC 2025',
#    'description': 'Recorded in front of a live audience at The California Theatre in San Jose Tuesday evening, special guests Joanna Stern and Nilay Patel join me to discuss Apple’s announcements at WWDC 2025.',
#    'url': 'https://daringfireball.net/2025/06/the_talk_show_live_from_wwdc_2025',
#    'urlToImage': 'https://daringfireball.net/graphics/df-wide-card.png',
#    'publishedAt': '2025-06-14T14:38:29Z',
#    'content': 'Recorded in front of a live audience at The California Theatre in San Jose Tuesday evening, special guests Joanna Stern and Nilay Patel join me to discuss Apple’s announcements at WWDC 2025.\n\n\n\r\n\n\n3D… [+1158 chars]'},
#   {'source': {'id': None, 'name': 'Simonwillison.net'},
#    'author': 'John Gruber',
#    'title': 'Seven Replies to the Viral Apple Reasoning Paper',
#    'description': 'A few weeks ago Apple Research released a new paper The Illusion of Thinking: Understanding the Strengths and Limitations of Reasoning Models via the Lens of Problem Complexity. Through extensive …',
#    'url': 'https://simonwillison.net/2025/Jun/15/viral-apple-reasoning-paper/',
#    'urlToImage': None,
#    'publishedAt': '2025-06-17T19:50:08Z',
#    'content': 'Seven replies to the viral Apple reasoning paper and why they fall short (via) A few weeks ago Apple Research released a new paper The Illusion of Thinking: Understanding the Strengths and Limitation… [+2606 chars]'},
#   {'source': {'id': 'le-monde', 'name': 'Le Monde'},
#    'author': 'Frédéric Potet',
#    'title': '«\xa0La France buissonnière\xa0»\xa0: les échappées numériques du cartographe à vélo',
#    'description': 'Antoine Lenoir, un développeur informatique de 28\xa0ans, sillonne à vélo les rues de Tours et des communes avoisinantes en quête de données pour alimenter OpenStreetMap, un vague concurrent de Google Maps conçu de manière collaborative.',
#    'url': 'https://www.lemonde.fr/m-perso/article/2025/06/16/la-france-buissonniere-les-echappees-numeriques-du-cartographe-a-velo_6613492_4497916.html',
#    'urlToImage': 'https://img.lemde.fr/2025/06/11/168/0/4032/2688/1440/960/60/0/a1a0215_sirius-fs-upload-1-e3geru5pmiq5-1749612350635-img-9968.jpg',
#    'publishedAt': '2025-06-16T04:00:20Z',
#    'content': 'Antoine Lenoir dans les rues de Tours, le 6\xa0juin. FP\r\nQuand dautres taquinent le goujon ou ramassent des champignons, Antoine Lenoir collecte des données cartographiques. Chaque week-end, dès larrivé… [+1620 chars]'},
#   {'source': {'id': None, 'name': 'Gizmodo.com'},
#    'author': 'Cheryl Eddy',
#    'title': 'Everything to Remember About ‘Foundation’ Season 2 Ahead of Season 3',
#    'description': 'The Apple TV+ Isaac Asimov adaptation returns soon for more sci-fi rulers, freaky math, and warfare both physical and psychic—are you ready?',
#    'url': 'https://gizmodo.com/everything-to-remember-about-foundation-season-2-ahead-of-season-3-2000616107',
#    'urlToImage': 'https://gizmodo.com/app/uploads/2025/06/Demerzel-1200x675.jpg',
#    'publishedAt': '2025-06-17T19:10:43Z',
#    'content': 'Foundation season three will pick up 152 years after the end of season two, which means a new set of supporting characters is on the way. However, given Foundations fondness for clones (be they organ… [+10860 chars]'},
#   {'source': {'id': None, 'name': 'Gizmodo.com'},
#    'author': 'Mike Fazioli',
#    'title': 'The Samsung Galaxy Watch Ultra Now Costs Less Than the Apple Watch Series 10 With or Without Trade-In',
#    'description': "Take advantage of Samsung's great $325 trade-in offer or get $200 off without sending in an old device and get their top-level smartwatch at a great price.",
#    'url': 'https://gizmodo.com/the-samsung-galaxy-watch-ultra-now-costs-less-than-the-apple-watch-series-10-with-or-without-trade-in-2000615807',
#    'urlToImage': 'https://gizmodo.com/app/uploads/2024/12/Galaxy-watch-Ultra-.jpeg',
#    'publishedAt': '2025-06-16T15:40:08Z',
#    'content': 'Samsung wants your smartwatch. Or your smartphone. Or your wireless earbuds. Relax they’re not robbing you. In fact, they want your old stuff so they can give you new, better stuff up to $325 in trad… [+2418 chars]'},
#   {'source': {'id': None, 'name': 'Gizmodo.com'},
#    'author': 'Gizmodo Deals',
#    'title': 'With 50 Hours of Battery Life, These Beats Headphones Are at a New Record Low on Amazon',
#    'description': 'For under $100, you get a premium audio headset from a top brand with advanced features.',
#    'url': 'https://gizmodo.com/with-50-hours-of-battery-life-these-beats-headphones-are-at-a-new-record-low-on-amazon-2000615397',
#    'urlToImage': 'https://gizmodo.com/app/uploads/2024/10/beats-solo-4-2.jpg',
#    'publishedAt': '2025-06-15T11:40:17Z',
#    'content': 'Right now, all of those looking to purchase a pair of decent and style-conscious wireless headphones should have the Beats Solo 4 on their radar, especially given that they’re also priced at their al… [+2276 chars]'},
#   {'source': {'id': None, 'name': 'Gizmodo.com'},
#    'author': 'Gizmodo Deals',
#    'title': 'Amazon Found a Way to Sell the MacBook Air 2025 at a Ridiculous Price, Much Cheaper Than on the Apple Store',
#    'description': "The MacBook gets 4.8 out of 5 and it's our favorite laptop for 2025.",
#    'url': 'https://gizmodo.com/amazon-found-a-way-to-sell-the-macbook-air-2025-at-a-ridiculous-price-much-cheaper-than-on-the-apple-store-2000616211',
#    'urlToImage': 'https://gizmodo.com/app/uploads/2025/05/macbook-air-2025-midnight-1200x675.jpg',
#    'publishedAt': '2025-06-16T14:25:16Z',
#    'content': 'On the official Apple site, the new MacBook Air laptops that debuted in March are, naturally, still at full retail price. But on Amazon, the MacBook Air 2025 256GB with the M4 chip is available for o… [+2445 chars]'},
#   {'source': {'id': None, 'name': 'Gizmodo.com'},
#    'author': 'Joe Tilleli',
#    'title': 'Forget Anker, UGREEN 4-Port USB-C Charger Drops to Almost Free and Has the Amazon’s Choice Badge',
#    'description': 'Save 40% on this 65W charging block from UGREEN for a limited time at Amazon.',
#    'url': 'https://gizmodo.com/forget-anker-ugreen-4-port-usb-c-charger-drops-to-almost-free-and-has-the-amazons-choice-badge-2000615695',
#    'urlToImage': 'https://gizmodo.com/app/uploads/2025/06/UGREENUSBCCharger-1200x675.jpg',
#    'publishedAt': '2025-06-16T12:10:05Z',
#    'content': 'Do ever find your different devices fighting for that one available outlet? Its annoying having to make the tough call to which youll plug in, your phone or your laptop. You can connect one and then … [+2228 chars]'},
#   {'source': {'id': None, 'name': 'Gizmodo.com'},
#    'author': 'Gizmodo Deals',
#    'title': 'This is Officially the Cheapest Dyson Vacuum You Can Find, Just Like on Black Friday',
#    'description': 'If we had to recommend a single Dyson model, this is the one we would suggest.',
#    'url': 'https://gizmodo.com/this-is-officially-the-cheapest-dyson-vacuum-you-can-find-just-like-on-black-friday-2000616139',
#    'urlToImage': 'https://gizmodo.com/app/uploads/2025/03/Dyson-V8-1200x675.jpg',
#    'publishedAt': '2025-06-16T11:10:23Z',
#    'content': 'Dyson is a brand that commands prestige in the world of home appliances, much like Apple does in consumer electronics. Its a company that rarely offers significant discounts and keeps its reputation … [+2604 chars]'},
#   {'source': {'id': None, 'name': 'Substack.com'},
#    'author': 'Gary Marcus',
#    'title': 'Seven replies to the viral Apple reasoning paper – and why they fall short',
#    'description': 'Also: another paper that seals the deal',
#    'url': 'https://garymarcus.substack.com/p/seven-replies-to-the-viral-apple',
#    'urlToImage': 'https://substackcdn.com/image/fetch/w_1200,h_600,c_fill,f_jpg,q_auto:good,fl_progressive:steep,g_auto/https%3A%2F%2Fbucketeer-e05bbc84-baa3-437e-9518-adb32be77984.s3.amazonaws.com%2Fpublic%2Fimages%2F8fb2e48c-be2a-4db7-b68c-90300f00fd1e_1668x1456.jpeg',
#    'publishedAt': '2025-06-14T19:52:38Z',
#    'content': 'The Apple paper on limitations in the reasoning of Large Reasoning Models, which raised challenges for the latest scaling hypothesis, has clearly touched a nerve. Tons of media outlets covered it; hu… [+8275 chars]'},
#   {'source': {'id': None, 'name': 'Victoramartinez.com'},
#    'author': '',
#    'title': "Why Claude's Comment Paper Is a Poor Rebuttal",
#    'description': 'Recently Apple published a paper on LRMs (Large Reasoning Models) and how they found that “that LRMs have limitations in exact computation” and that “they fail to use explicit algorithms and reason inconsistently across puzzles.” I would consider this a death…',
#    'url': 'https://victoramartinez.com/posts/why-claudes-comment-paper-is-a-poor-rebuttal/',
#    'urlToImage': 'https://victoramartinez.com/',
#    'publishedAt': '2025-06-16T01:46:42Z',
#    'content': 'Recently Apple published a paper on LRMs (Large Reasoning Models) and how they found that “that LRMs have limitations in exact computation” and that “they fail to use explicit algorithms and reason i… [+5483 chars]'},
#   {'source': {'id': None, 'name': 'Angad.me'},
#    'author': 'Angad Behl',
#    'title': 'Getting free internet on a cruise, saving $170',
#    'description': 'Internet on a cruise ship is insanely expensive, but a little bit of DevTools knowledge and some simple Python scripting can go a long way when it comes to getting free internet',
#    'url': 'https://angad.me/blog/2025/getting-free-cruise-internet/',
#    'urlToImage': 'https://angad.me/blog/2025/getting-free-cruise-internet/speed-test-comparison.jpg',
#    'publishedAt': '2025-06-16T17:38:45Z',
#    'content': 'Picture this, you’re a teenager in the middle of the ocean on a cruise ship. All is good, except you’re lacking your lifeblood: internet. You could pay $170 for seven days of throttled internet on a … [+12196 chars]'},
#   {'source': {'id': None, 'name': 'Professoraxelrod.com'},
#    'author': 'Professor Axelrod',
#    'title': 'The Tech Job Meltdown',
#    'description': "Half a million layoffs? It's all accounting.",
#    'url': 'https://www.professoraxelrod.com/p/the-tech-job-meltdown',
#    'urlToImage': 'https://substackcdn.com/image/fetch/w_1200,h_600,c_fill,f_jpg,q_auto:good,fl_progressive:steep,g_auto/https%3A%2F%2Fsubstack-post-media.s3.amazonaws.com%2Fpublic%2Fimages%2F2c9872ad-e90e-49c8-be04-2f03ac64653b_1167x486.webp',
#    'publishedAt': '2025-06-14T02:22:54Z',
#    'content': "He wrote me a prescription; he said You are depressedI'm glad you came to see me to get this off your chestCome back and see me later, next patient pleaseSend in another victim of industrial diseaseI… [+16066 chars]"},
#   {'source': {'id': None, 'name': 'Mertbulan.com'},
#    'author': None,
#    'title': "Munich from a Hamburger's Perspective",
#    'description': "A first-time visitor from Hamburg reflects on Munich's royal roots, museums, and surprising contrasts between two of Germany's most iconic cities.",
#    'url': 'https://mertbulan.com/2025/06/14/munich-from-a-hamburgers-perspective/',
#    'urlToImage': 'https://mertbulan.com/images/posts/munich/residenz.webp',
#    'publishedAt': '2025-06-15T20:55:25Z',
#    'content': 'Over the long weekend, thanks to Whit Monday being a public holiday in Germany, I decided to visit a friend who lives in Munich. I spent about three and a half days there and thought it would be a go… [+13231 chars]'},
#   {'source': {'id': None, 'name': 'Placing.technology'},
#    'author': None,
#    'title': 'Notes on the History of the Map Tile',
#    'description': 'Web map tiles—the storing of geospatial data at different zoom levels in x/y/z indexed squares of raster (and later, vector) data for efficient',
#    'url': 'https://placing.technology/notes-on-the-history-of-the-map-tile',
#    'urlToImage': 'https://cdn.blot.im/blog_0f2525f3e5cc43839a22f2e74259050f/_thumbnails/346035a8-b986-4b59-b27c-97b21547eaf8/large.png',
#    'publishedAt': '2025-06-15T09:14:09Z',
#    'content': 'Web map tilesthe storing of geospatial data at different zoom levels in x/y/z indexed squares of raster (and later, vector) data for efficient storage and transmission of digital mapsare, despite the… [+14041 chars]'},
#   {'source': {'id': None, 'name': 'Wheresyoured.at'},
#    'author': 'Edward Zitron',
#    'title': 'Sincerity Wins the War',
#    'description': 'Hello Where’s Your Ed At Subscribers! I’ve started a premium version of this newsletter with a weekly Friday column where I go over the most meaningful news and give my views, which I guess is what you’d expect. Anyway, it’s $7 a month or $70 a year, and help…',
#    'url': 'https://www.wheresyoured.at/sic/',
#    'urlToImage': 'https://www.wheresyoured.at/content/images/2024/01/wyea--1.jpeg',
#    'publishedAt': '2025-06-16T16:45:56Z',
#    'content': 'Hello Wheres Your Ed At Subscribers! Ive started a premium version of this newsletter with a weekly Friday column where I go over the most meaningful news and give my views, which I guess is what you… [+49318 chars]'},
#   {'source': {'id': 'buzzfeed', 'name': 'Buzzfeed'},
#    'author': 'Angelica Martinez',
#    'title': 'A Month After Trump Threatened Apple And Samsung With 25% Tariffs, The Trump Organization Has Launched Their Own $499 "Trump Mobile" Smartphones',
#    'description': "As if the MAGA hats weren't bad enough, a shiny new bombshell has entered the villa.View Entire Post ›",
#    'url': 'https://www.buzzfeed.com/angelicaamartinez/trump-mobile-smartphone-internet-reactions',
#    'urlToImage': 'https://img.buzzfeed.com/buzzfeed-static/static/2025-06/16/18/thumb/9mmlJT9_P.jpg?crop=1250:655;0,155%26downsize=1250:*',
#    'publishedAt': '2025-06-16T20:31:53Z',
#    'content': 'The grift never ends: From the crime family that proudly gave us Trump Steaks, Trump Vodka, Trump Daddy Diapers, and Trump Colostomy Bags... Ladies and gentlemen, the Trump crime family proudly intro… [+88 chars]'}]}
